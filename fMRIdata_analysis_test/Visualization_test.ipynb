# %%
参照：https://miykael.github.io/nipype_tutorial/notebooks/example_preprocessing.html

from nilearn import image, plotting
# %matplotlib inline

# %%
plotting.plot_epi(
    '/Users/ryoheieguchi/Downloads/sub-01_ses-retest_anat_sub-01_ses-retest_T1w.nii',
    title="T1", display_mode='ortho', annotate=False, draw_cross=False, cmap='gray');
